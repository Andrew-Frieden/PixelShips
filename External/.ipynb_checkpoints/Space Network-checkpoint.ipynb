# %%
import numpy as np
import scipy as sp
import random as rand
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class room:
    def __init__(self, id):
        self.exits = []
        self.exitCt = 0
        self.id = id
    
    def toString(self):
        return "Room: %d Exct: %s Exits: %s" %(self.id,self.exitCt,self.exits)

# %%
testRoom = room(1)
print(testRoom.toString())
# Out:
# Room: 1 Exct: 0 Exits: []

# %%
def roomBuilder(rmList, rmCt):
    maxNeighbors = np.log(rmCt)
    
    for i in range(rmCt + 1):
        newRoom = room(i + 1)
        neighbor = rmList[rand.randint(0,i)]
        
        while (len(neighbor.exits) >= maxNeighbors):
            neighbor = rmList[rand.randint(0,i)]
        
        
        newRoom.exitCt += 1
        newRoom.exits.append(neighbor.id)
        if ((neighbor.exitCt > 1) and (rand.random() > 0.5)):
            loopRoom = neighbor.exits[rand.randint(0,len(neighbor.exits) -1)]
            newRoom.exitCt +=1
            newRoom.exits.append(loopRoom)
            rmList[loopRoom].exits.append(newRoom.id)
            rmList[loopRoom].exitCt += 1
            
        neighbor.exits.append(newRoom.id)
        neighbor.exitCt += 1
            
            
        
        rmList.append(newRoom)

    return rmList

# %%
rand.seed(2)

rmList = []
newRoom = room(0)
rmList.append(newRoom)
rmList = roomBuilder(rmList, 25)

for i in range(len(rmList)):
    print (rmList[i].toString())
# Out:
# Room: 0 Exct: 4 Exits: [1, 2, 3, 6]
# Room: 1 Exct: 3 Exits: [0, 4, 12]
# Room: 2 Exct: 4 Exits: [0, 5, 6, 8]
# Room: 3 Exct: 1 Exits: [0]
# Room: 4 Exct: 3 Exits: [1, 7, 12]
# Room: 5 Exct: 5 Exits: [2, 10, 13, 14, 15]
# Room: 6 Exct: 4 Exits: [2, 0, 8, 9]
# Room: 7 Exct: 4 Exits: [4, 16, 17, 21]
# Room: 8 Exct: 4 Exits: [2, 6, 9, 11]
# Room: 9 Exct: 5 Exits: [6, 8, 11, 23, 24]
# Room: 10 Exct: 3 Exits: [5, 14, 18]
# Room: 11 Exct: 4 Exits: [8, 9, 23, 24]
# Room: 12 Exct: 2 Exits: [4, 1]
# Room: 13 Exct: 1 Exits: [5]
# Room: 14 Exct: 4 Exits: [5, 10, 15, 22]
# Room: 15 Exct: 3 Exits: [14, 5, 22]
# Room: 16 Exct: 4 Exits: [7, 19, 20, 21]
# Room: 17 Exct: 1 Exits: [7]
# Room: 18 Exct: 1 Exits: [10]
# Room: 19 Exct: 1 Exits: [16]
# Room: 20 Exct: 1 Exits: [16]
# Room: 21 Exct: 2 Exits: [16, 7]
# Room: 22 Exct: 2 Exits: [14, 15]
# Room: 23 Exct: 3 Exits: [11, 9, 26]
# Room: 24 Exct: 3 Exits: [11, 9, 25]
# Room: 25 Exct: 1 Exits: [24]
# Room: 26 Exct: 1 Exits: [23]

# %%
G=nx.Graph()
listOfExits = []


for i in range(len(rmList)):
    G.add_node(i)
    listOfExits.append(rmList[i].exitCt)
    
for i in range(len(rmList)):
    for j in range(len(rmList[i].exits)):
        G.add_edge(i,rmList[i].exits[j])

# %%
plt.set_cmap('cool')
plt.figure(figsize=(12,12))
pos = nx.spring_layout(G,dim=2, iterations=100, scale= 100, center=(0,0))
nx.draw(G, node_size=200, with_labels=True, font_size=8, node_color=(listOfExits), pos=pos)
plt.show()
print(pos)
# Out:
# {0: array([ 5.52359229, -1.32208415]), 1: array([ -1.20901053,  24.52089322]), 2: array([  2.72108174, -23.2003437 ]), 3: array([ 11.14109496,   7.48244459]), 4: array([ -7.2832518 ,  46.70264173]), 5: array([-18.51242578, -40.28942237]), 6: array([ 16.44657023, -17.8658948 ]), 7: array([-13.88658147,  69.44458114]), 8: array([ 21.82191253, -26.83901722]), 9: array([ 33.62573011, -27.80916884]), 10: array([-29.11508606, -54.97729761]), 11: array([ 37.87366376, -32.33593131]), 12: array([ -3.95389458,  36.65869249]), 13: array([-14.84996942, -51.72597534]), 14: array([-32.22394061, -46.22969763]), 15: array([-33.42139963, -39.72388798]), 16: array([-22.92838657,  86.48809453]), 17: array([ -5.58720304,  78.21742282]), 18: array([-36.32369782, -67.50986597]), 19: array([-33.44710776,  94.54392372]), 20: array([ -23.2078549,  100.       ]), 21: array([-20.63778813,  78.48326848]), 22: array([-43.3792147 , -44.06026045]), 23: array([ 49.26384394, -28.55546357]), 24: array([ 44.27360515, -40.62871458]), 25: array([ 53.75531649, -51.23705447]), 26: array([ 63.52040163, -28.23188272])}

# %%
for i in range(len(pos)):
    tempstr = str(i) + ' ' + str(pos[i][0]) + ' ' + str(pos[i][1]) + ' ' + str(rmList[i].exits)
    print(tempstr)
# Out:
# 0 5.52359228757 -1.32208414873 [1, 2, 3, 6]
# 1 -1.20901053206 24.5208932186 [0, 4, 12]
# 2 2.721081738 -23.2003437049 [0, 5, 6, 8]
# 3 11.1410949568 7.48244459028 [0]
# 4 -7.28325180142 46.7026417279 [1, 7, 12]
# 5 -18.5124257842 -40.2894223693 [2, 10, 13, 14, 15]
# 6 16.4465702306 -17.8658947956 [2, 0, 8, 9]
# 7 -13.8865814713 69.4445811395 [4, 16, 17, 21]
# 8 21.8219125307 -26.8390172212 [2, 6, 9, 11]
# 9 33.6257301091 -27.8091688442 [6, 8, 11, 23, 24]
# 10 -29.1150860614 -54.9772976136 [5, 14, 18]
# 11 37.8736637648 -32.3359313059 [8, 9, 23, 24]
# 12 -3.95389458318 36.6586924931 [4, 1]
# 13 -14.8499694194 -51.7259753391 [5]
# 14 -32.2239406057 -46.2296976341 [5, 10, 15, 22]
# 15 -33.4213996318 -39.7238879752 [14, 5, 22]
# 16 -22.9283865738 86.4880945265 [7, 19, 20, 21]
# 17 -5.58720304372 78.2174228244 [7]
# 18 -36.3236978187 -67.5098659738 [10]
# 19 -33.4471077557 94.5439237155 [16]
# 20 -23.2078549041 100.0 [16]
# 21 -20.6377881307 78.4832684804 [16, 7]
# 22 -43.3792147049 -44.0602604544 [14, 15]
# 23 49.2638439372 -28.5554635736 [11, 9, 26]
# 24 44.2736051454 -40.6287145765 [11, 9, 25]
# 25 53.755316487 -51.2370544688 [24]
# 26 63.5204016349 -28.231882717 [23]
